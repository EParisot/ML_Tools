# %%
import os
import numpy as np
import pandas as pd
import json
from PIL import Image
import random
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import cv2
import keras
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
import tensorflow.keras.optimizers as Optimizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical, Sequence
from tensorflow.keras import activations

# %%
data_path = "data_horse"
labels_file = "data_horse/bboxes.json"
img_size = (128, 128, 3)

# %%
colors = [(255, 0, 0),
           (0, 0, 255),
           (0, 255, 0),
           (0, 255, 255),
           (0, 102, 0),
           (255, 0, 255),
           (255, 255, 0),
           (255, 102, 255),
           (0, 51, 102),
           (51, 153, 255)]

labels_ref = [
    "0",
    "1"
]

# %%
class_nb = 2
nb_boxes = 4
grid_w = 5
grid_h = 5
cell_w = img_size[0] // grid_w
cell_h = img_size[1] // grid_h
img_w = grid_w * cell_w
img_h = grid_h * cell_h

batch_size = 8

# %%
rotations = [0, 90, 180, 270]
class DataGenerator(Sequence):
    def __init__(self, data, data_path, class_nb, batch_size=16, shuffle=False, preprocess=None):
        super().__init__()
        self.data = data
        self.file_names = np.array(list(self.data.keys()))
        self.class_nb = class_nb
        self.shuffle = shuffle
        self.batch_size = batch_size
        self.preprocess = preprocess
        self.data_path = data_path
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.data) / self.batch_size))
    
    def on_epoch_end(self):
        self.indexes = np.arange(len(self.data))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)
    
    def preprocess(X):
        return X
    
    def __getitem__(self, index):
        X = np.empty((self.batch_size, img_size[1], img_size[0], img_size[2]), dtype=np.float32)
        Y = np.empty((self.batch_size, grid_w, grid_h, nb_boxes, (class_nb + 5)), dtype=np.float32)
        indexes = self.indexes[index * self.batch_size : (index + 1) * self.batch_size]
        for i, f in enumerate([self.file_names[idx] for idx in indexes]):
            rot_idx = np.random.randint(4)
            
            im = Image.open(os.path.join(self.data_path, f)).resize((img_size[0], img_size[1]))
            im = im.rotate(rotations[rot_idx])
            X[i,] = np.array(im) / 255.0
            rects = []
            
            boxes = self.data[f]
            for class_id in boxes.keys():
                for box in boxes[class_id]:
                    x, y, w, h = box[0], box[1], box[2], box[3]
                    rects.append([x, y, w, h])

            # rotate rects
            if rot_idx == 0:
                pass
            elif rot_idx == 1:
                rects = [[r[1], 1-r[0], r[3], r[2]] for r in rects]
            elif rot_idx == 2:
                rects = [[1-r[0], 1-r[1], r[2], r[3]] for r in rects]
            else:
                rects = [[1-r[1], r[0], r[3], r[2]] for r in rects]
            Y[i,] = build_yolo_out(rects, Y[i,])
        if self.preprocess!=None: 
            X = self.preprocess(X)
        return X, Y

# %%
def rect_is_in_cell(rect, row, col):
    if rect[0] * img_w > col * cell_w and rect[0] * img_w <= col * cell_w + cell_w and \
        rect[1] * img_h > row * cell_h and rect[1] * img_h <= row * cell_h + cell_h:
            return True
    return False

def build_yolo_out(data, y_t):
    for row in range(grid_h):
        for col in range(grid_w):
            found = False
            class_id = 1
            rects = []
            for rect in data:
                if rect_is_in_cell(rect, row, col):
                    rects.append(rect)

            if len(rects):
                #class
                c_t = list(to_categorical(class_id, num_classes=class_nb))
                #confidence
                conf_t = [1]
                elt = []
                
                for j, rect in enumerate(rects):

                    #define center position and w h
                    cx = rect[0] if rect[0] >= 0 else 0
                    cy = rect[1] if rect[1] >= 0 else 0
                    cw = rect[2] if rect[2] >= 0 else 0
                    ch = rect[3] if rect[3] >= 0 else 0
                    cx = cx if cx <= 1 else 1
                    cy = cy if cy <= 1 else 1
                    cw = cw if cw <= 1 else 1
                    ch = ch if ch <= 1 else 1
                    x = cx * img_w
                    y = cy * img_h
                    rel_x = (x - (col * cell_w)) / cell_w
                    rel_y = (y - (row * cell_h)) / cell_h
                    [x, y, w, h] = [rel_x, rel_y, cw, ch]
                    if len(rects) > 1:
                        if j < len(rects)-1:
                            for b in range(nb_boxes // len(rects)):
                                elt.append(c_t + [x, y, w, h] + conf_t)
                        else:
                            for b in range((nb_boxes // len(rects)) + (nb_boxes % len(rects))):
                                elt.append(c_t + [x, y, w, h] + conf_t)
                    else:
                        for b in range(nb_boxes):
                                elt.append(c_t + [x, y, w, h] + conf_t)
                y_t[row][col] = elt
                found = True

            if found == False:
                #class
                c_t = list(to_categorical(0, num_classes=class_nb))
                #define center position and w h
                rel_x = (cell_w / 2) / cell_w
                rel_y = (cell_h / 2) / cell_h
                [x, y, w, h] = [rel_x, rel_y, cell_w / img_w, cell_h / img_h]
                #confidence
                conf_t = [0]
                elt = []
                for b in range(nb_boxes):
                    elt.append(c_t + [x, y, w, h] + conf_t)
                y_t[row][col] = elt
    
    return y_t

# %%
with open(labels_file) as f:
    dict_data = json.load(f)

shuffled_dict_keys = list(dict_data.keys())
random.shuffle(shuffled_dict_keys)
shuffled_dict_data = dict()
for key in shuffled_dict_keys:
    shuffled_dict_data.update({key:dict_data[key]})
                
batch_size = 8
train_batches = DataGenerator(shuffled_dict_data, data_path, class_nb, batch_size=batch_size)

# %%
for batch in train_batches:
    for i in range(batch_size):
        fig, axes = plt.subplots()
        img = (batch[0][i,] * 255).astype('uint8')
        
        for row, _ in enumerate(batch[1][i]):
            for col, label in enumerate(batch[1][i][row]):
                #print(label.shape, label)
                for box in label:
                    if np.argmax(box[:class_nb]) != 0:
                        x = (box[class_nb + 0] * cell_w) + (col * cell_w)
                        y = (box[class_nb + 1] * cell_h) + (row * cell_h) 

                        #print(x, y, box[class_nb + 2]* img_w, box[class_nb + 3]* img_h)
                        pt1 = (int(x - (box[class_nb + 2] * img_w / 2)), \
                               int(y - (box[class_nb + 3] * img_h / 2)))
                        pt2 = (int(x + (box[class_nb + 2] * img_w / 2)), \
                               int(y + (box[class_nb + 3] * img_h / 2)))
                        cv2.rectangle(img, pt1, pt2, colors[np.argmax(box[:class_nb])], thickness=2)
        plt.imshow(img)
        for row in range(grid_w):
            plt.axvline(x=row*cell_w,color='black')
        for col in range(grid_h):
            plt.axhline(y=col*cell_h,color='black')
    break

# %%
import tensorflow_addons as tfa

f_loss = tfa.losses.SigmoidFocalCrossEntropy()

def custom_loss(y_true, y_pred):

    y_true_class = K.reshape(y_true[...,:class_nb], (-1, grid_w, grid_h, nb_boxes, class_nb))
    y_pred_class = K.reshape(y_pred[...,:class_nb], (-1, grid_w, grid_h, nb_boxes, class_nb))

    pred_boxes = K.reshape(y_pred[...,class_nb:], (-1, grid_w, grid_h, nb_boxes, 5))
    true_boxes = K.reshape(y_true[...,class_nb:], (-1, grid_w, grid_h, nb_boxes, 5))
    
    y_pred_xy   = pred_boxes[...,0:2]
    y_pred_wh   = pred_boxes[...,2:4]
    y_pred_conf = pred_boxes[...,4]

    y_true_xy   = true_boxes[...,0:2]
    y_true_wh   = true_boxes[...,2:4]
    y_true_conf = true_boxes[...,4]

    clss_loss  = K.sum(f_loss(y_true_class, y_pred_class), axis=-1)
    xy_loss    = K.sum(K.sum(K.square(y_true_xy - y_pred_xy),axis=-1)*y_true_conf, axis=-1)
    wh_loss    = K.sum(K.sum(K.square(K.sqrt(y_true_wh) - K.sqrt(y_pred_wh)), axis=-1)*y_true_conf, axis=-1)

    # when we add the confidence the box prediction lower in quality but we gain the estimation of the quality of the box
    # however the training is a bit unstable

    # minimum distance between boxes distance between the two center
    intersect_wh = K.maximum(K.zeros_like(y_pred_wh), (y_pred_wh + y_true_wh)/2 - K.abs(y_pred_xy - y_true_xy) )
    intersect_area = intersect_wh[...,0] * intersect_wh[...,1]
    true_area = y_true_wh[...,0] * y_true_wh[...,1]
    pred_area = y_pred_wh[...,0] * y_pred_wh[...,1]
    union_area = pred_area + true_area - intersect_area
    iou = intersect_area / union_area

    conf_loss = K.sum(K.square(y_true_conf*iou - y_pred_conf)*y_true_conf, axis=-1)

    return clss_loss + xy_loss + wh_loss + conf_loss

# %%
K.clear_session()

leaky_alpha = 0.1

img_in = Input(shape=(img_size[1], img_size[0], img_size[2]), name='img_in')

x = Conv2D(16, 1, padding='same')(img_in)
x = Conv2D(32, 3, strides=2,padding='same')(x)
x = LeakyReLU(alpha=leaky_alpha)(x)
x = BatchNormalization()(x)

x = Conv2D(16, 1, padding='same')(x)
x = Conv2D(32, 3, strides=2, padding='same')(x)
x = LeakyReLU(alpha=leaky_alpha)(x)
x = BatchNormalization()(x)

x = Conv2D(32, 1, padding='same')(x)
x = Conv2D(64, 3, strides=2, padding='same')(x)
x = Conv2D(64, 1, padding='same')(x)
x = LeakyReLU(alpha=leaky_alpha)(x)
x = BatchNormalization()(x)

x = Conv2D(64, 1, padding='same')(x)
x = Conv2D(128, 1, padding='same')(x)
x = LeakyReLU(alpha=leaky_alpha)(x)
x = BatchNormalization()(x)

x = Conv2D(nb_boxes * (class_nb + 5), 3, 3, activation="sigmoid")(x)
out = Reshape((grid_h, grid_w, nb_boxes, class_nb + 5))(x)

model = Model(inputs=[img_in], outputs=[out])

model.compile(optimizer=Optimizers.Adam(learning_rate=1e-4), loss=custom_loss)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img_in (InputLayer)          [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 16)      64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64, 64, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        528
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        1056
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        4160
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        4160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 128)       8320
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 5, 5, 28)          32284
# _________________________________________________________________
# reshape (Reshape)            (None, 5, 5, 4, 7)        0
# =================================================================
# Total params: 79,372
# Trainable params: 78,860
# Non-trainable params: 512
# _________________________________________________________________

# %%
model_name = "model_horse_128_c.h5"
#save best model if model improved
best_checkpoint = ModelCheckpoint(model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
idx = int(0.8*len(shuffled_dict_data))
train_data = {k: shuffled_dict_data[k] for k in list(shuffled_dict_data)[:idx]}
val_data = {k: shuffled_dict_data[k] for k in list(shuffled_dict_data)[idx:]}

train_batches = DataGenerator(train_data, data_path, class_nb, batch_size=batch_size, shuffle=True)
val_batches = DataGenerator(val_data, data_path, class_nb, batch_size=batch_size)

# %%
history = model.fit(train_batches, validation_data = val_batches, epochs = 200, verbose=1, callbacks=[best_checkpoint])
# Out:
# Epoch 1/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.0924 - val_loss: 0.1775
#
# Epoch 00001: val_loss did not improve from 0.14945
# Epoch 2/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0904 - val_loss: 0.1667
#
# Epoch 00002: val_loss did not improve from 0.14945
# Epoch 3/200
# 18/18 [==============================] - ETA: 0s - loss: 0.090 - 1s 39ms/step - loss: 0.0907 - val_loss: 0.1606
#
# Epoch 00003: val_loss did not improve from 0.14945
# Epoch 4/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0882 - val_loss: 0.1985
#
# Epoch 00004: val_loss did not improve from 0.14945
# Epoch 5/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0865 - val_loss: 0.1779
#
# Epoch 00005: val_loss did not improve from 0.14945
# Epoch 6/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0899 - val_loss: 0.1635
#
# Epoch 00006: val_loss did not improve from 0.14945
# Epoch 7/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0886 - val_loss: 0.1575
#
# Epoch 00007: val_loss did not improve from 0.14945
# Epoch 8/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0863 - val_loss: 0.1485
#
# Epoch 00008: val_loss improved from 0.14945 to 0.14850, saving model to model_horse_128_c.h5
# Epoch 9/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0813 - val_loss: 0.1659
#
# Epoch 00009: val_loss did not improve from 0.14850
# Epoch 10/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0825 - val_loss: 0.1681
#
# Epoch 00010: val_loss did not improve from 0.14850
# Epoch 11/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0817 - val_loss: 0.2157
#
# Epoch 00011: val_loss did not improve from 0.14850
# Epoch 12/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0837 - val_loss: 0.1774
#
# Epoch 00012: val_loss did not improve from 0.14850
# Epoch 13/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0832 - val_loss: 0.1738
#
# Epoch 00013: val_loss did not improve from 0.14850
# Epoch 14/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0822 - val_loss: 0.1759
#
# Epoch 00014: val_loss did not improve from 0.14850
# Epoch 15/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0822 - val_loss: 0.1590
#
# Epoch 00015: val_loss did not improve from 0.14850
# Epoch 16/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0882 - val_loss: 0.1872
#
# Epoch 00016: val_loss did not improve from 0.14850
# Epoch 17/200
# 18/18 [==============================] - 1s 44ms/step - loss: 0.0836 - val_loss: 0.1843
#
# Epoch 00017: val_loss did not improve from 0.14850
# Epoch 18/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.0749 - val_loss: 0.1528
#
# Epoch 00018: val_loss did not improve from 0.14850
# Epoch 19/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0764 - val_loss: 0.1716
#
# Epoch 00019: val_loss did not improve from 0.14850
# Epoch 20/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0810 - val_loss: 0.1908
#
# Epoch 00020: val_loss did not improve from 0.14850
# Epoch 21/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0793 - val_loss: 0.1682
#
# Epoch 00021: val_loss did not improve from 0.14850
# Epoch 22/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0784 - val_loss: 0.1988
#
# Epoch 00022: val_loss did not improve from 0.14850
# Epoch 23/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0755 - val_loss: 0.1760
#
# Epoch 00023: val_loss did not improve from 0.14850
# Epoch 24/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0762 - val_loss: 0.1665
#
# Epoch 00024: val_loss did not improve from 0.14850
# Epoch 25/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0766 - val_loss: 0.1541
#
# Epoch 00025: val_loss did not improve from 0.14850
# Epoch 26/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0770 - val_loss: 0.1635
#
# Epoch 00026: val_loss did not improve from 0.14850
# Epoch 27/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0782 - val_loss: 0.1626
#
# Epoch 00027: val_loss did not improve from 0.14850
# Epoch 28/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.0736 - val_loss: 0.1861
#
# Epoch 00028: val_loss did not improve from 0.14850
# Epoch 29/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0755 - val_loss: 0.1581
#
# Epoch 00029: val_loss did not improve from 0.14850
# Epoch 30/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0751 - val_loss: 0.1777
#
# Epoch 00030: val_loss did not improve from 0.14850
# Epoch 31/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0783 - val_loss: 0.1772
#
# Epoch 00031: val_loss did not improve from 0.14850
# Epoch 32/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0733 - val_loss: 0.1671
#
# Epoch 00032: val_loss did not improve from 0.14850
# Epoch 33/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0730 - val_loss: 0.2003
#
# Epoch 00033: val_loss did not improve from 0.14850
# Epoch 34/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0734 - val_loss: 0.1883
#
# Epoch 00034: val_loss did not improve from 0.14850
# Epoch 35/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0691 - val_loss: 0.1794
#
# Epoch 00035: val_loss did not improve from 0.14850
# Epoch 36/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0722 - val_loss: 0.1815
#
# Epoch 00036: val_loss did not improve from 0.14850
# Epoch 37/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0711 - val_loss: 0.1495
#
# Epoch 00037: val_loss did not improve from 0.14850
# Epoch 38/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0699 - val_loss: 0.1881
#
# Epoch 00038: val_loss did not improve from 0.14850
# Epoch 39/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0737 - val_loss: 0.1883
#
# Epoch 00039: val_loss did not improve from 0.14850
# Epoch 40/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0693 - val_loss: 0.1698
#
# Epoch 00040: val_loss did not improve from 0.14850
# Epoch 41/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0669 - val_loss: 0.1639
#
# Epoch 00041: val_loss did not improve from 0.14850
# Epoch 42/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0628 - val_loss: 0.1551
#
# Epoch 00042: val_loss did not improve from 0.14850
# Epoch 43/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0682 - val_loss: 0.1708
#
# Epoch 00043: val_loss did not improve from 0.14850
# Epoch 44/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0708 - val_loss: 0.1780
#
# Epoch 00044: val_loss did not improve from 0.14850
# Epoch 45/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0690 - val_loss: 0.1830
#
# Epoch 00045: val_loss did not improve from 0.14850
# Epoch 46/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0706 - val_loss: 0.1874
#
# Epoch 00046: val_loss did not improve from 0.14850
# Epoch 47/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0714 - val_loss: 0.1819
#
# Epoch 00047: val_loss did not improve from 0.14850
# Epoch 48/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0667 - val_loss: 0.1872
#
# Epoch 00048: val_loss did not improve from 0.14850
# Epoch 49/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0672 - val_loss: 0.1828
#
# Epoch 00049: val_loss did not improve from 0.14850
# Epoch 50/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0653 - val_loss: 0.1969
#
# Epoch 00050: val_loss did not improve from 0.14850
# Epoch 51/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0682 - val_loss: 0.1813
#
# Epoch 00051: val_loss did not improve from 0.14850
# Epoch 52/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0659 - val_loss: 0.2027
#
# Epoch 00052: val_loss did not improve from 0.14850
# Epoch 53/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0612 - val_loss: 0.1911
#
# Epoch 00053: val_loss did not improve from 0.14850
# Epoch 54/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0613 - val_loss: 0.1771
#
# Epoch 00054: val_loss did not improve from 0.14850
# Epoch 55/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0583 - val_loss: 0.2045
#
# Epoch 00055: val_loss did not improve from 0.14850
# Epoch 56/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0625 - val_loss: 0.2245
#
# Epoch 00056: val_loss did not improve from 0.14850
# Epoch 57/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0612 - val_loss: 0.1887
#
# Epoch 00057: val_loss did not improve from 0.14850
# Epoch 58/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0620 - val_loss: 0.2232
#
# Epoch 00058: val_loss did not improve from 0.14850
# Epoch 59/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0613 - val_loss: 0.1640
#
# Epoch 00059: val_loss did not improve from 0.14850
# Epoch 60/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0629 - val_loss: 0.1993
#
# Epoch 00060: val_loss did not improve from 0.14850
# Epoch 61/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0652 - val_loss: 0.1881
#
# Epoch 00061: val_loss did not improve from 0.14850
# Epoch 62/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0610 - val_loss: 0.2122
#
# Epoch 00062: val_loss did not improve from 0.14850
# Epoch 63/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0571 - val_loss: 0.1801
#
# Epoch 00063: val_loss did not improve from 0.14850
# Epoch 64/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0561 - val_loss: 0.1970
#
# Epoch 00064: val_loss did not improve from 0.14850
# Epoch 65/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0561 - val_loss: 0.1625
#
# Epoch 00065: val_loss did not improve from 0.14850
# Epoch 66/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0587 - val_loss: 0.1543
#
# Epoch 00066: val_loss did not improve from 0.14850
# Epoch 67/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0632 - val_loss: 0.1821
#
# Epoch 00067: val_loss did not improve from 0.14850
# Epoch 68/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0588 - val_loss: 0.1886
#
# Epoch 00068: val_loss did not improve from 0.14850
# Epoch 69/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0573 - val_loss: 0.1788
#
# Epoch 00069: val_loss did not improve from 0.14850
# Epoch 70/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0538 - val_loss: 0.1643
#
# Epoch 00070: val_loss did not improve from 0.14850
# Epoch 71/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0593 - val_loss: 0.1755
#
# Epoch 00071: val_loss did not improve from 0.14850
# Epoch 72/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0557 - val_loss: 0.1634
#
# Epoch 00072: val_loss did not improve from 0.14850
# Epoch 73/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0560 - val_loss: 0.1896
#
# Epoch 00073: val_loss did not improve from 0.14850
# Epoch 74/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0556 - val_loss: 0.1948
#
# Epoch 00074: val_loss did not improve from 0.14850
# Epoch 75/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0544 - val_loss: 0.1786
#
# Epoch 00075: val_loss did not improve from 0.14850
# Epoch 76/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0572 - val_loss: 0.1662
#
# Epoch 00076: val_loss did not improve from 0.14850
# Epoch 77/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0548 - val_loss: 0.1878
#
# Epoch 00077: val_loss did not improve from 0.14850
# Epoch 78/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0562 - val_loss: 0.2005
#
# Epoch 00078: val_loss did not improve from 0.14850
# Epoch 79/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0570 - val_loss: 0.2118
#
# Epoch 00079: val_loss did not improve from 0.14850
# Epoch 80/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0520 - val_loss: 0.2398
#
# Epoch 00080: val_loss did not improve from 0.14850
# Epoch 81/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0522 - val_loss: 0.1978
#
# Epoch 00081: val_loss did not improve from 0.14850
# Epoch 82/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0536 - val_loss: 0.2225
#
# Epoch 00082: val_loss did not improve from 0.14850
# Epoch 83/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0526 - val_loss: 0.1647
#
# Epoch 00083: val_loss did not improve from 0.14850
# Epoch 84/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0542 - val_loss: 0.2392
#
# Epoch 00084: val_loss did not improve from 0.14850
# Epoch 85/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0551 - val_loss: 0.1973
#
# Epoch 00085: val_loss did not improve from 0.14850
# Epoch 86/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0528 - val_loss: 0.2110
#
# Epoch 00086: val_loss did not improve from 0.14850
# Epoch 87/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0576 - val_loss: 0.1760
#
# Epoch 00087: val_loss did not improve from 0.14850
# Epoch 88/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0536 - val_loss: 0.1839
#
# Epoch 00088: val_loss did not improve from 0.14850
# Epoch 89/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0569 - val_loss: 0.1704
#
# Epoch 00089: val_loss did not improve from 0.14850
# Epoch 90/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0573 - val_loss: 0.1737
#
# Epoch 00090: val_loss did not improve from 0.14850
# Epoch 91/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0482 - val_loss: 0.1980
#
# Epoch 00091: val_loss did not improve from 0.14850
# Epoch 92/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0476 - val_loss: 0.2292
#
# Epoch 00092: val_loss did not improve from 0.14850
# Epoch 93/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0490 - val_loss: 0.2080
#
# Epoch 00093: val_loss did not improve from 0.14850
# Epoch 94/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0449 - val_loss: 0.2012
#
# Epoch 00094: val_loss did not improve from 0.14850
# Epoch 95/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0526 - val_loss: 0.2260
#
# Epoch 00095: val_loss did not improve from 0.14850
# Epoch 96/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0477 - val_loss: 0.2212
#
# Epoch 00096: val_loss did not improve from 0.14850
# Epoch 97/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0486 - val_loss: 0.2521
#
# Epoch 00097: val_loss did not improve from 0.14850
# Epoch 98/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0462 - val_loss: 0.2202
#
# Epoch 00098: val_loss did not improve from 0.14850
# Epoch 99/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0472 - val_loss: 0.2143
#
# Epoch 00099: val_loss did not improve from 0.14850
# Epoch 100/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0536 - val_loss: 0.2063
#
# Epoch 00100: val_loss did not improve from 0.14850
# Epoch 101/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0466 - val_loss: 0.2116
#
# Epoch 00101: val_loss did not improve from 0.14850
# Epoch 102/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0501 - val_loss: 0.2353
#
# Epoch 00102: val_loss did not improve from 0.14850
# Epoch 103/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0499 - val_loss: 0.2318
#
# Epoch 00103: val_loss did not improve from 0.14850
# Epoch 104/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0472 - val_loss: 0.1843
#
# Epoch 00104: val_loss did not improve from 0.14850
# Epoch 105/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0468 - val_loss: 0.2181
#
# Epoch 00105: val_loss did not improve from 0.14850
# Epoch 106/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0507 - val_loss: 0.2288
#
# Epoch 00106: val_loss did not improve from 0.14850
# Epoch 107/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0485 - val_loss: 0.2197
# Epoch 00107: val_loss did not improve from 0.14850
# Epoch 108/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0531 - val_loss: 0.2361
#
# Epoch 00108: val_loss did not improve from 0.14850
# Epoch 109/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0432 - val_loss: 0.2145
#
# Epoch 00109: val_loss did not improve from 0.14850
# Epoch 110/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0455 - val_loss: 0.2043
#
# Epoch 00110: val_loss did not improve from 0.14850
# Epoch 111/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0445 - val_loss: 0.1827
#
# Epoch 00111: val_loss did not improve from 0.14850
# Epoch 112/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0437 - val_loss: 0.2042TA: 0s - loss: 0.0
#
# Epoch 00112: val_loss did not improve from 0.14850
# Epoch 113/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0461 - val_loss: 0.2364
#
# Epoch 00113: val_loss did not improve from 0.14850
# Epoch 114/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0455 - val_loss: 0.2232
#
# Epoch 00114: val_loss did not improve from 0.14850
# Epoch 115/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0407 - val_loss: 0.2378
#
# Epoch 00115: val_loss did not improve from 0.14850
# Epoch 116/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0408 - val_loss: 0.2109
#
# Epoch 00116: val_loss did not improve from 0.14850
# Epoch 117/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0451 - val_loss: 0.1986
#
# Epoch 00117: val_loss did not improve from 0.14850
# Epoch 118/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0440 - val_loss: 0.1972
#
# Epoch 00118: val_loss did not improve from 0.14850
# Epoch 119/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0407 - val_loss: 0.1865
#
# Epoch 00119: val_loss did not improve from 0.14850
# Epoch 120/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0408 - val_loss: 0.2503
#
# Epoch 00120: val_loss did not improve from 0.14850
# Epoch 121/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0402 - val_loss: 0.2156
#
# Epoch 00121: val_loss did not improve from 0.14850
# Epoch 122/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0384 - val_loss: 0.2502
#
# Epoch 00122: val_loss did not improve from 0.14850
# Epoch 123/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0375 - val_loss: 0.2245
#
# Epoch 00123: val_loss did not improve from 0.14850
# Epoch 124/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0416 - val_loss: 0.2149
#
# Epoch 00124: val_loss did not improve from 0.14850
# Epoch 125/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0409 - val_loss: 0.2328
#
# Epoch 00125: val_loss did not improve from 0.14850
# Epoch 126/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0418 - val_loss: 0.2255
#
# Epoch 00126: val_loss did not improve from 0.14850
# Epoch 127/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0416 - val_loss: 0.2219
#
# Epoch 00127: val_loss did not improve from 0.14850
# Epoch 128/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0405 - val_loss: 0.1981
#
# Epoch 00128: val_loss did not improve from 0.14850
# Epoch 129/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0432 - val_loss: 0.2279
#
# Epoch 00129: val_loss did not improve from 0.14850
# Epoch 130/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0354 - val_loss: 0.2451
#
# Epoch 00130: val_loss did not improve from 0.14850
# Epoch 131/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0408 - val_loss: 0.2485
#
# Epoch 00131: val_loss did not improve from 0.14850
# Epoch 132/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0382 - val_loss: 0.2705
#
# Epoch 00132: val_loss did not improve from 0.14850
# Epoch 133/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0389 - val_loss: 0.2196
#
# Epoch 00133: val_loss did not improve from 0.14850
# Epoch 134/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0370 - val_loss: 0.1916
#
# Epoch 00134: val_loss did not improve from 0.14850
# Epoch 135/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0368 - val_loss: 0.2400
#
# Epoch 00135: val_loss did not improve from 0.14850
# Epoch 136/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0371 - val_loss: 0.2561
#
# Epoch 00136: val_loss did not improve from 0.14850
# Epoch 137/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0380 - val_loss: 0.2756
#
# Epoch 00137: val_loss did not improve from 0.14850
# Epoch 138/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0385 - val_loss: 0.2230
#
# Epoch 00138: val_loss did not improve from 0.14850
# Epoch 139/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0358 - val_loss: 0.2469
#
# Epoch 00139: val_loss did not improve from 0.14850
# Epoch 140/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0380 - val_loss: 0.2207
#
# Epoch 00140: val_loss did not improve from 0.14850
# Epoch 141/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0372 - val_loss: 0.2303
#
# Epoch 00141: val_loss did not improve from 0.14850
# Epoch 142/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0385 - val_loss: 0.2782
#
# Epoch 00142: val_loss did not improve from 0.14850
# Epoch 143/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0353 - val_loss: 0.2610
#
# Epoch 00143: val_loss did not improve from 0.14850
# Epoch 144/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0345 - val_loss: 0.2265
#
# Epoch 00144: val_loss did not improve from 0.14850
# Epoch 145/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0364 - val_loss: 0.2061
#
# Epoch 00145: val_loss did not improve from 0.14850
# Epoch 146/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0367 - val_loss: 0.2431
#
# Epoch 00146: val_loss did not improve from 0.14850
# Epoch 147/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0366 - val_loss: 0.2669
#
# Epoch 00147: val_loss did not improve from 0.14850
# Epoch 148/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0343 - val_loss: 0.2386
#
# Epoch 00148: val_loss did not improve from 0.14850
# Epoch 149/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0377 - val_loss: 0.2796
#
# Epoch 00149: val_loss did not improve from 0.14850
# Epoch 150/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0365 - val_loss: 0.1880
#
# Epoch 00150: val_loss did not improve from 0.14850
# Epoch 151/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0325 - val_loss: 0.2525
#
# Epoch 00151: val_loss did not improve from 0.14850
# Epoch 152/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0336 - val_loss: 0.2850
#
# Epoch 00152: val_loss did not improve from 0.14850
# Epoch 153/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0360 - val_loss: 0.2636
#
# Epoch 00153: val_loss did not improve from 0.14850
# Epoch 154/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0340 - val_loss: 0.2493
#
# Epoch 00154: val_loss did not improve from 0.14850
# Epoch 155/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0322 - val_loss: 0.2166
#
# Epoch 00155: val_loss did not improve from 0.14850
# Epoch 156/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0347 - val_loss: 0.2918
#
# Epoch 00156: val_loss did not improve from 0.14850
# Epoch 157/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0319 - val_loss: 0.2994
#
# Epoch 00157: val_loss did not improve from 0.14850
# Epoch 158/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0337 - val_loss: 0.2404
#
# Epoch 00158: val_loss did not improve from 0.14850
# Epoch 159/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0345 - val_loss: 0.2698
#
# Epoch 00159: val_loss did not improve from 0.14850
# Epoch 160/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0337 - val_loss: 0.2815
#
# Epoch 00160: val_loss did not improve from 0.14850
# Epoch 161/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0330 - val_loss: 0.3036
#
# Epoch 00161: val_loss did not improve from 0.14850
# Epoch 162/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0327 - val_loss: 0.2557
#
# Epoch 00162: val_loss did not improve from 0.14850
# Epoch 163/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0349 - val_loss: 0.3022
#
# Epoch 00163: val_loss did not improve from 0.14850
# Epoch 164/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0337 - val_loss: 0.2467
#
# Epoch 00164: val_loss did not improve from 0.14850
# Epoch 165/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0309 - val_loss: 0.2452
#
# Epoch 00165: val_loss did not improve from 0.14850
# Epoch 166/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0340 - val_loss: 0.2604
#
# Epoch 00166: val_loss did not improve from 0.14850
# Epoch 167/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0347 - val_loss: 0.2570
#
# Epoch 00167: val_loss did not improve from 0.14850
# Epoch 168/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0313 - val_loss: 0.2110
#
# Epoch 00168: val_loss did not improve from 0.14850
# Epoch 169/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0295 - val_loss: 0.2831
#
# Epoch 00169: val_loss did not improve from 0.14850
# Epoch 170/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0338 - val_loss: 0.2571
#
# Epoch 00170: val_loss did not improve from 0.14850
# Epoch 171/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0311 - val_loss: 0.2193
#
# Epoch 00171: val_loss did not improve from 0.14850
# Epoch 172/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0300 - val_loss: 0.3163
#
# Epoch 00172: val_loss did not improve from 0.14850
# Epoch 173/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0343 - val_loss: 0.2994
#
# Epoch 00173: val_loss did not improve from 0.14850
# Epoch 174/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0316 - val_loss: 0.3739
#
# Epoch 00174: val_loss did not improve from 0.14850
# Epoch 175/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0325 - val_loss: 0.3381
#
# Epoch 00175: val_loss did not improve from 0.14850
# Epoch 176/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0419 - val_loss: 0.3124
#
# Epoch 00176: val_loss did not improve from 0.14850
# Epoch 177/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0396 - val_loss: 0.2990
#
# Epoch 00177: val_loss did not improve from 0.14850
# Epoch 178/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0324 - val_loss: 0.2872
#
# Epoch 00178: val_loss did not improve from 0.14850
# Epoch 179/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0285 - val_loss: 0.2740
#
# Epoch 00179: val_loss did not improve from 0.14850
# Epoch 180/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0293 - val_loss: 0.2482
#
# Epoch 00180: val_loss did not improve from 0.14850
# Epoch 181/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0319 - val_loss: 0.2348
#
# Epoch 00181: val_loss did not improve from 0.14850
# Epoch 182/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0297 - val_loss: 0.2410
#
# Epoch 00182: val_loss did not improve from 0.14850
# Epoch 183/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0307 - val_loss: 0.2969
#
# Epoch 00183: val_loss did not improve from 0.14850
# Epoch 184/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0259 - val_loss: 0.3224
#
# Epoch 00184: val_loss did not improve from 0.14850
# Epoch 185/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0270 - val_loss: 0.2949
#
# Epoch 00185: val_loss did not improve from 0.14850
# Epoch 186/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0272 - val_loss: 0.2591
#
# Epoch 00186: val_loss did not improve from 0.14850
# Epoch 187/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0255 - val_loss: 0.2558
#
# Epoch 00187: val_loss did not improve from 0.14850
# Epoch 188/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0256 - val_loss: 0.2501
#
# Epoch 00188: val_loss did not improve from 0.14850
# Epoch 189/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0262 - val_loss: 0.3377
#
# Epoch 00189: val_loss did not improve from 0.14850
# Epoch 190/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0287 - val_loss: 0.3327
#
# Epoch 00190: val_loss did not improve from 0.14850
# Epoch 191/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0280 - val_loss: 0.2711
#
# Epoch 00191: val_loss did not improve from 0.14850
# Epoch 192/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0281 - val_loss: 0.3044
#
# Epoch 00192: val_loss did not improve from 0.14850
# Epoch 193/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0270 - val_loss: 0.3236
#
# Epoch 00193: val_loss did not improve from 0.14850
# Epoch 194/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0275 - val_loss: 0.2968
#
# Epoch 00194: val_loss did not improve from 0.14850
# Epoch 195/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0276 - val_loss: 0.2447
#
# Epoch 00195: val_loss did not improve from 0.14850
# Epoch 196/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0326 - val_loss: 0.2823
#
# Epoch 00196: val_loss did not improve from 0.14850
# Epoch 197/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0294 - val_loss: 0.3079
#
# Epoch 00197: val_loss did not improve from 0.14850
# Epoch 198/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0279 - val_loss: 0.2512
#
# Epoch 00198: val_loss did not improve from 0.14850
# Epoch 199/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0279 - val_loss: 0.2855
#
# Epoch 00199: val_loss did not improve from 0.14850
# Epoch 200/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0256 - val_loss: 0.2798
#
# Epoch 00200: val_loss did not improve from 0.14850

# %%
#print History graph
historydf = pd.DataFrame(history.history, index=history.epoch)
historydf.plot(ylim=(0,1))
# Out:
# <AxesSubplot:>

# %%
# LOAD MODEL

from tensorflow.keras.models import load_model
from deepctr.layers import custom_objects

custom_objects["custom_loss"] = custom_loss
model = load_model(model_name, custom_objects=custom_objects)

# %%
nb = 0
for batch in val_batches:
    nb += 1
    for i in range(batch_size):
        
        img = (batch[0][i,] * 255).astype('uint8')
        fig, axes = plt.subplots()
        
        for row, _ in enumerate(batch[1][i]):
            for col, label in enumerate(batch[1][i][row]):
                #print(label.shape, label)
                for box in label:
                    if np.argmax(box[:class_nb]) != 0:
                        x = (box[class_nb + 0] * cell_w) + (col * cell_w)
                        y = (box[class_nb + 1] * cell_h) + (row * cell_h) 
                        pt1 = (int(x - (box[class_nb + 2] * img_w / 2)), \
                               int(y - (box[class_nb + 3] * img_h / 2)))
                        pt2 = (int(x + (box[class_nb + 2] * img_w / 2)), \
                               int(y + (box[class_nb + 3] * img_h / 2)))
                        cv2.rectangle(img, pt1, pt2, [0, 0, 255], thickness=2)
                        
        pred = model.predict(np.expand_dims(batch[0][i,], axis=0))
        for row, _ in enumerate(pred[0]):
            for col, label in enumerate(pred[0][row]):
                #print(label.shape, label)
                for box in label:
                    #if np.argmax(box[:class_nb]) != 0:
                    if box[1] > 0.5:
                        x = (box[class_nb + 0] * cell_w) + (col * cell_w)
                        y = (box[class_nb + 1] * cell_h) + (row * cell_h) 
                        pt1 = (int(x - (box[class_nb + 2] * img_w / 2)), \
                               int(y - (box[class_nb + 3] * img_h / 2)))
                        pt2 = (int(x + (box[class_nb + 2] * img_w / 2)), \
                               int(y + (box[class_nb + 3] * img_h / 2)))
                        cv2.rectangle(img, pt1, pt2, [255, 0, 0], 2)
                        
        axes.imshow(img)
        for row in range(grid_w):
            axes.axvline(x=row*cell_w,color='black')
        for col in range(grid_h):
            axes.axhline(y=col*cell_h,color='black')
        fig.show() 
    if nb > 0:
        break
# Out:
# C:\Users\Rock_\AppData\Local\Temp/ipykernel_34832/3286463896.py:42: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
